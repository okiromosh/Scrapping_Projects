# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
#url = ('https://books.toscrape.com/catalogue/page-1.html')
#page = requests.get(url)

# %%
#soup = BeautifulSoup(page.text, 'html')

# %%
#soup.title.text.strip()
soup.find('p', class_='instock availability').text.strip()
# Out:
# 'In stock'

# %%
data = []
current_page = 1
proceed = True

while (proceed):
  print(f'Currently scrapping: {current_page}')
  url = (f'https://books.toscrape.com/catalogue/page-{current_page}.html')
  page = requests.get(url)
  soup = BeautifulSoup(page.text, 'html')
  if soup.title.text == '404 Not Found':
    proceed = False
  else:
    all_books = soup.find_all('li', class_='col-xs-6 col-sm-4 col-md-3 col-lg-3')

    for book in all_books:
      item = {}

      item['Title'] = book.find('img').attrs['alt']
      item['Link'] = book.find('a').attrs['href']
      item['Price'] = book.find('p', class_='price_color').text[1:]
      item['Stock'] = book.find('p', class_='instock availability').text.strip()

      data.append(item)

  current_page += 1
# Out:
# Currently scrapping: 1
# Currently scrapping: 2
# Currently scrapping: 3
# Currently scrapping: 4
# Currently scrapping: 5
# Currently scrapping: 6
# Currently scrapping: 7
# Currently scrapping: 8
# Currently scrapping: 9
# Currently scrapping: 10
# Currently scrapping: 11
# Currently scrapping: 12
# Currently scrapping: 13
# Currently scrapping: 14
# Currently scrapping: 15
# Currently scrapping: 16
# Currently scrapping: 17
# Currently scrapping: 18
# Currently scrapping: 19
# Currently scrapping: 20
# Currently scrapping: 21
# Currently scrapping: 22
# Currently scrapping: 23
# Currently scrapping: 24
# Currently scrapping: 25
# Currently scrapping: 26
# Currently scrapping: 27
# Currently scrapping: 28
# Currently scrapping: 29
# Currently scrapping: 30
# Currently scrapping: 31
# Currently scrapping: 32
# Currently scrapping: 33
# Currently scrapping: 34
# Currently scrapping: 35
# Currently scrapping: 36
# Currently scrapping: 37
# Currently scrapping: 38
# Currently scrapping: 39
# Currently scrapping: 40
# Currently scrapping: 41
# Currently scrapping: 42
# Currently scrapping: 43
# Currently scrapping: 44
# Currently scrapping: 45
# Currently scrapping: 46
# Currently scrapping: 47
# Currently scrapping: 48
# Currently scrapping: 49
# Currently scrapping: 50
# Currently scrapping: 51

# %%
df = pd.DataFrame(data)
df
# Out:
#                                                  Title  \
# 0                                 A Light in the Attic
# 1                                   Tipping the Velvet
# 2                                           Soumission
# 3                                        Sharp Objects
# 4                Sapiens: A Brief History of Humankind
# ..                                                 ...
# 995  Alice in Wonderland (Alice's Adventures in Won...
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997  A Spy's Devotion (The Regency Spies of London #1)
# 998                1st to Die (Women's Murder Club #1)
# 999                 1,000 Places to See Before You Die
#
#                                                   Link   Price     Stock
# 0                 a-light-in-the-attic_1000/index.html  £51.77  In stock
# 1                    tipping-the-velvet_999/index.html  £53.74  In stock
# 2                            soumission_998/index.html  £50.10  In stock
# 3                         sharp-objects_997/index.html  £47.82  In stock
# 4    sapiens-a-brief-history-of-humankind_996/index...  £54.23  In stock
# ..                                                 ...     ...       ...
# 995  alice-in-wonderland-alices-adventures-in-wonde...  £55.53  In stock
# 996  ajin-demi-human-volume-1-ajin-demi-human-1_4/i...  £57.06  In stock
# 997  a-spys-devotion-the-regency-spies-of-london-1_...  £16.97  In stock
# 998       1st-to-die-womens-murder-club-1_2/index.html  £53.98  In stock
# 999     1000-places-to-see-before-you-die_1/index.html  £26.08  In stock
#
# [1000 rows x 4 columns]

# %%
df.to_csv('Books Data.csv')
#df.to_excel('Books Data.xlxs')
